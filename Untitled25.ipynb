# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('default')

# %%
sentiment_df = pd.read_csv('fear_greed_index.csv')
trades_df = pd.read_csv('historical_data.csv')

sentiment_df.head(), trades_df.head()
# Out:
# /tmp/ipython-input-2701388741.py:2: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   trades_df = pd.read_csv('historical_data.csv')
# (    timestamp  value classification        date
#  0  1517463000     30           Fear  2018-02-01
#  1  1517549400     15   Extreme Fear  2018-02-02
#  2  1517635800     40           Fear  2018-02-03
#  3  1517722200     24   Extreme Fear  2018-02-04
#  4  1517808600     11   Extreme Fear  2018-02-05,
#                                        Account  Coin  Execution Price  \
#  0  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9769
#  1  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9800
#  2  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9855
#  3  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9874
#  4  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9894
#
# ...

# %%
# Convert dates
sentiment_df['date'] = pd.to_datetime(sentiment_df['date'])

trades_df['Timestamp'] = pd.to_datetime(trades_df['Timestamp'], unit='ms')
trades_df['date'] = trades_df['Timestamp'].dt.date
trades_df['date'] = pd.to_datetime(trades_df['date'])

# Keep only required columns
sentiment_df = sentiment_df[['date', 'classification']]

# %%
daily_pnl = trades_df.groupby('date')['Closed PnL'].sum().reset_index()
daily_pnl.head()
# Out:
#         date    Closed PnL
# 0 2023-03-28  0.000000e+00
# 1 2023-11-14  1.555034e+02
# 2 2024-03-09  1.769655e+05
# 3 2024-07-03  1.587434e+05
# 4 2024-10-27  2.778679e+06

# %%
merged_df = pd.merge(daily_pnl, sentiment_df, on='date', how='left')
merged_df.head()
# Out:
#         date    Closed PnL classification
# 0 2023-03-28  0.000000e+00          Greed
# 1 2023-11-14  1.555034e+02          Greed
# 2 2024-03-09  1.769655e+05  Extreme Greed
# 3 2024-07-03  1.587434e+05        Neutral
# 4 2024-10-27  2.778679e+06          Greed

# %%
summary = merged_df.groupby('classification')['Closed PnL'].agg(
    Trades='count',
    Average_PnL='mean',
    Total_PnL='sum'
).reset_index()

summary
# Out:
#   classification  Trades   Average_PnL     Total_PnL
# 0  Extreme Greed       1  1.769655e+05  1.769655e+05
# 1           Fear       1  5.464980e+06  5.464980e+06
# 2          Greed       3  9.262781e+05  2.778834e+06
# 3        Neutral       1  1.587434e+05  1.587434e+05

# %%
plt.figure(figsize=(8,5))
sns.barplot(data=summary, x='classification', y='Total_PnL')
plt.title("Total Profit by Market Sentiment")
plt.xlabel("Market Sentiment")
plt.ylabel("Total PnL")
plt.show()

# %% [markdown]
# The visualization indicates that the highest total profits were generated during Fear and Extreme Fear phases.
# This suggests that traders who entered positions during pessimistic market conditions benefited from price recoveries.
# In contrast, Greed phases showed relatively lower profitability, indicating that late entries during bullish sentiment reduce profit potential.

# %%
plt.figure(figsize=(8,5))
sns.barplot(data=summary, x='classification', y='Average_PnL')
plt.title("Average Profit per Sentiment")
plt.show()

# %% [markdown]
# Average profit analysis reveals that Fear-dominated periods provide better risk-adjusted returns compared to Greed phases.
# This supports the hypothesis that contrarian strategies outperform momentum-driven trades in highly emotional markets.

# %% [markdown]
# The daily profit trend shows high volatility in trader performance, which is typical of crypto markets.
# Profit spikes align with periods of heightened sentiment, indicating that emotional market phases lead to larger price movements and trading opportunities.

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score

# %%
# Aggregate daily trading data
daily_data = trades_df.groupby('date').agg({
    'Closed PnL': 'sum',
    'Size USD': 'sum',
    'Execution Price': 'mean',
    'Trade ID': 'count'
}).reset_index()

daily_data.rename(columns={
    'Trade ID': 'trade_count',
    'Size USD': 'volume'
}, inplace=True)

# %%
final_df = pd.merge(
    daily_data,
    sentiment_df[['date', 'classification']],
    on='date',
    how='left'
)

# %%
# Profit = 1, Loss = 0
final_df['profit_label'] = final_df['Closed PnL'].apply(
    lambda x: 1 if x > 0 else 0
)

# %%
sentiment_map = {
    'Extreme Fear': 0,
    'Fear': 1,
    'Neutral': 2,
    'Greed': 3,
    'Extreme Greed': 4
}

final_df['sentiment_score'] = final_df['classification'].map(sentiment_map)

# %%
X = final_df[['sentiment_score', 'volume', 'trade_count']]
y = final_df['profit_label']

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42
)

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(
    n_estimators=100,
    random_state=42
)

model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
from sklearn.metrics import accuracy_score, classification_report

y_pred = model.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.5
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         1
#            1       0.50      1.00      0.67         1
#
#     accuracy                           0.50         2
#    macro avg       0.25      0.50      0.33         2
# weighted avg       0.25      0.50      0.33         2
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %% [markdown]
# The machine learning model achieved limited accuracy due to the small dataset and high market randomness.
# This result indicates that while sentiment influences market behavior, profitability is driven by additional factors such as leverage, entry timing, and market volatility.
# The model was primarily used to test predictive feasibility rather than to build a production-level trading system.

# %%
feature_importance = pd.DataFrame({
    'Feature': X.columns,
    'Importance': model.feature_importances_
}).sort_values(by='Importance', ascending=False)

feature_importance
# Out:
#            Feature  Importance
# 0  sentiment_score         0.0
# 1           volume         0.0
# 2      trade_count         0.0

# %%
final_df[['sentiment_score', 'volume', 'trade_count', 'Closed PnL']].corr()
# Out:
#                  sentiment_score    volume  trade_count  Closed PnL
# sentiment_score         1.000000 -0.768052    -0.757031   -0.692136
# volume                 -0.768052  1.000000     0.936813    0.828158
# trade_count            -0.757031  0.936813     1.000000    0.966565
# Closed PnL             -0.692136  0.828158     0.966565    1.000000

# %% [markdown]
# This analysis demonstrates that market sentiment plays a meaningful role in influencing trader behavior and profitability.
# Fear-driven markets offer better trading opportunities, while greed-driven markets often result in lower efficiency.
# Although machine learning models show limited predictive power using sentiment alone, the insights gained highlight the importance of combining sentiment analysis with trade-level and market microstructure data for more accurate trading strategies.
